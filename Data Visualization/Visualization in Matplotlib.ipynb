# %%
import numpy as np

"""
By convention, we import the library under a shorter name
"""

import matplotlib as mpl

"""
Specifically, the module matplotlib.pyplot, a collection of command style functions that make matplotlib work like MATLAB, will be used for the rest of the course

Specifically, the module matplotlib.pyplot, will be used for the rest of the course :
"""

import matplotlib.pyplot as plt

# %%
"""
The style can be changed from classic to ggplot, mimicking the aesthetic style used in the R package ggplot2.
"""

plt.style.use('ggplot')

# %%
"""
matplotlib.pyplot is a collection of functions that make plotting in python work like MATLAB

For all matplotlib plots, 
first create a figure and an axes object; 
to show the plot, call “plt.show()”. 
The figure contains all the objects, including axes, graphics, texts, and labels. 
The axes is a bounding box with ticks and labels. 
Think of axes as an individual plot.
"""

fig = plt.figure()
ax = plt.axes()
plt.savefig('fig.png')
plt.show()

# %%
x = np.linspace(0,10,1000) # x is a 1000 evenly spaced numbers from 0 to 10

print(x)
# Out:
# [ 0.          0.01001001  0.02002002  0.03003003  0.04004004  0.05005005
#   0.06006006  0.07007007  0.08008008  0.09009009  0.1001001   0.11011011
#   0.12012012  0.13013013  0.14014014  0.15015015  0.16016016  0.17017017
#   0.18018018  0.19019019  0.2002002   0.21021021  0.22022022  0.23023023
#   0.24024024  0.25025025  0.26026026  0.27027027  0.28028028  0.29029029
#   0.3003003   0.31031031  0.32032032  0.33033033  0.34034034  0.35035035
#   0.36036036  0.37037037  0.38038038  0.39039039  0.4004004   0.41041041
#   0.42042042  0.43043043  0.44044044  0.45045045  0.46046046  0.47047047
#   0.48048048  0.49049049  0.5005005   0.51051051  0.52052052  0.53053053
#   0.54054054  0.55055055  0.56056056  0.57057057  0.58058058  0.59059059
#   0.6006006   0.61061061  0.62062062  0.63063063  0.64064064  0.65065065
#   0.66066066  0.67067067  0.68068068  0.69069069  0.7007007   0.71071071
#   0.72072072  0.73073073  0.74074074  0.75075075  0.76076076  0.77077077
# ...

# %%
y = np.sin(x)

fig = plt.figure()
ax = plt.axes()

"""
We now make a plot directly from the Axes, "ax.plot()"; 
by default, it generates a Line2D object. 
To show the plot, we need to call show().
"""

ax.plot(x, y)
plt.savefig("plot.png")
plt.show()

# %%
x = np.linspace(0,361,28)
y = np.sin(x)
fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)
plt.savefig("plot2.png")
plt.show()

#Alternatively, we can use the pylab interface and let the figure and axes be created for us in the background.

# %%
x = np.linspace(0,10,1000) # x is a 1000 evenly spaced numbers from 0 to 10
fig = plt.figure()
plt.plot(x, np.cos(x))#A line plot displays data along a number line, a useful tool to track changes over short and long periods of time.
plt.show()

# %%
"""
We can specify the x and y axis labels and a title using plt.xlabel(), plt.ylabel() and plt.title().
"""

x = np.linspace(0,10,1000) # 1darray of length 1000
y = np.sin(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('function sin(x)')
plt.savefig("plot.png")
plt.show()

# %%
#One can also set the limits of x- and y-axis using plt.xlim() and plt.ylim(), respectively.
x = np.linspace(0,360,60) # 1darray of length 1000
y = np.sin(x)


plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('function sin(x) with limits for x and y')
plt.xlim((0,360))
plt.ylim((-1,1))
plt.savefig("plot.png")
plt.show()

# %%
#we can plot them both on the same figure by calling the .plot() function multiple times.
#Colors and line styles can be specified to differentiate lines:

x = np.linspace(0,10,1000) # 1darray of length 1000
y = np.sin(x)
plt.title('function sin(x) and cos(x) and tan(x) and 1/tan(x)')
plt.xlim((0,10))
plt.ylim((-1,1))
plt.plot(x, np.sin(x),color = 'g')
plt.plot(x, np.cos(x),color='c')
plt.plot(x, np.tan(x), color='k')
plt.plot(x, 1/np.tan(x), color='r', linestyle ='--')

plt.savefig("plot.png")
plt.show()

"""
Note that we specified basic colors using a single letter, that is, k for black and r for red. More examples include b for blue, g for green, c for cyan, etc. For more details on the use of colors in matplotlib, refer to its documentation.

https://matplotlib.org/2.0.2/api/colors_api.html
"""
# Out:
# C:\Users\essam\AppData\Local\Temp\ipykernel_1812\290842739.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(x, 1/np.tan(x), color='r', linestyle ='--')
# '\nNote that we specified basic colors using a single letter, that is, k for black and r for red. More examples include b for blue, g for green, c for cyan, etc. For more details on the use of colors in matplotlib, refer to its documentation.\n\nhttps://matplotlib.org/2.0.2/api/colors_api.html\n'

# %%
"""
When there are multiple lines on a single axes, 
it’s often useful to create a plot legend labeling each line. 
We can use the method plt.legend(), in conjunction with specifying labels in the plt.plot()
"""

x = np.linspace(0,10,1000) # 1darray of length 1000
y = np.sin(x)
plt.plot(x, np.sin(x), 'k:', label='sin(x)')
plt.plot(x, np.cos(x), 'r--', label='cos(x)')
plt.legend()
plt.savefig("plot.png")
plt.show()

"""
Note here we use 'k:' to indicate the line of sin function to be black (indicated by k) and dotted (indicated by :). 
Line style and color codes can be combined into a single non-keyword argument in the plt.plot() function.

The color, line style (e.g., solid, dashed, etc.), and position, size, and style of labels can be modified using optional 
arguments to the function. For more details check the docstring of each function and the matplotlib documentation.

https://matplotlib.org/3.1.3/tutorials/index.html#colors
"""
# Out:
# "\nNote here we use 'k:' to indicate the line of sin function to be black (indicated by k) and dotted (indicated by :). \nLine style and color codes can be combined into a single non-keyword argument in the plt.plot() function.\n\nThe color, line style (e.g., solid, dashed, etc.), and position, size, and style of labels can be modified using optional \narguments to the function. For more details check the docstring of each function and the matplotlib documentation.\n\nhttps://matplotlib.org/3.1.3/tutorials/index.html#colors\n"
