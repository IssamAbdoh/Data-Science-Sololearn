# %%
"""
The Boston housing dataset is our sample dataset that provides median values of homes in different areas around Boston. 
Along with the median home values in $1000 (MEDV), 
crime (CRIM), 
nitric oxides concentration (NOX),
the average number of rooms (RM), 
percentage of lower status of the population (LSTAT), 
and other features are provided

Our objective is to predict median home price (MEDV)
"""

"""
A note :
The data from load_boston dataset is deprecated , thus I will be using fetch_california_housing dataset along the way

The Boston housing prices dataset has an ethical problem. You can refer to
the documentation of this function for further details.

The scikit-learn maintainers therefore strongly discourage the use of this
dataset unless the purpose of the code is to study and educate about
ethical issues in data science and machine learning.
"""

from sklearn.datasets import load_boston,fetch_california_housing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
california_housing_dataset = fetch_california_housing()

california_housing = pd.DataFrame(california_housing_dataset.data, columns=california_housing_dataset.feature_names)

#We then add the target into the DataFrame
california_housing['MEDV'] = california_housing_dataset.target

# %%
california_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude   MEDV
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
california_housing.shape
# Out:
# (20640, 9)

# %%
california_housing.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MEDV'],
#       dtype='object')

# %%
california_housing[['AveRooms','HouseAge','MEDV']].head()
# Out:
#    AveRooms  HouseAge   MEDV
# 0  6.984127      41.0  4.526
# 1  6.238137      21.0  3.585
# 2  8.288136      52.0  3.521
# 3  5.817352      52.0  3.413
# 4  6.281853      52.0  3.422

# %%
#print(boston[['CHAS', 'RM', 'AGE', 'RAD', 'MEDV']].head())

california_housing.describe().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude      MEDV
# count  20640.00   20640.00  20640.00
# mean      35.63    -119.57      2.07
# std        2.14       2.00      1.15
# min       32.54    -124.35      0.15
# 25%       33.93    -121.80      1.20
# 50%       34.26    -118.49      1.80
# 75%       37.71    -118.01      2.65
# max       41.95    -114.31      5.00

# %%
"""
If the DataFrame contains more than just numeric values, 
by default, describe() outputs the descriptive statistics for the numeric columns. 
To show the summary statistics of all column, specify include = 'all' in the method
"""

california_housing.describe(include = 'all').round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude      MEDV
# count  20640.00   20640.00  20640.00
# mean      35.63    -119.57      2.07
# std        2.14       2.00      1.15
# min       32.54    -124.35      0.15
# 25%       33.93    -121.80      1.20
# 50%       34.26    -118.49      1.80
# 75%       37.71    -118.01      2.65
# max       41.95    -114.31      5.00

# %%
#run this code to see sklearn message

boston_dataset = load_boston()
# Out:
# c:\Users\essam\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
boston = pd.DataFrame(boston_dataset.data,columns=boston_dataset.feature_names)
boston['MEDV'] = boston_dataset.target
boston.describe(include = 'all').round(2)
# Out:
#          CRIM      ZN   INDUS    CHAS     NOX      RM     AGE     DIS     RAD  \
# count  506.00  506.00  506.00  506.00  506.00  506.00  506.00  506.00  506.00
# mean     3.61   11.36   11.14    0.07    0.55    6.28   68.57    3.80    9.55
# std      8.60   23.32    6.86    0.25    0.12    0.70   28.15    2.11    8.71
# min      0.01    0.00    0.46    0.00    0.38    3.56    2.90    1.13    1.00
# 25%      0.08    0.00    5.19    0.00    0.45    5.89   45.02    2.10    4.00
# 50%      0.26    0.00    9.69    0.00    0.54    6.21   77.50    3.21    5.00
# 75%      3.68   12.50   18.10    0.00    0.62    6.62   94.07    5.19   24.00
# max     88.98  100.00   27.74    1.00    0.87    8.78  100.00   12.13   24.00
#
#           TAX  PTRATIO       B   LSTAT    MEDV
# count  506.00   506.00  506.00  506.00  506.00
# mean   408.24    18.46  356.67   12.65   22.53
# std    168.54     2.16   91.29    7.14    9.20
# min    187.00    12.60    0.32    1.73    5.00
# ...

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]
boston2 = pd.DataFrame(data,columns=boston_dataset.feature_names)
boston2.describe(include = 'all').round(2)
# Out:
#          CRIM      ZN   INDUS    CHAS     NOX      RM     AGE     DIS     RAD  \
# count  506.00  506.00  506.00  506.00  506.00  506.00  506.00  506.00  506.00
# mean     3.61   11.36   11.14    0.07    0.55    6.28   68.57    3.80    9.55
# std      8.60   23.32    6.86    0.25    0.12    0.70   28.15    2.11    8.71
# min      0.01    0.00    0.46    0.00    0.38    3.56    2.90    1.13    1.00
# 25%      0.08    0.00    5.19    0.00    0.45    5.89   45.02    2.10    4.00
# 50%      0.26    0.00    9.69    0.00    0.54    6.21   77.50    3.21    5.00
# 75%      3.68   12.50   18.10    0.00    0.62    6.62   94.07    5.19   24.00
# max     88.98  100.00   27.74    1.00    0.87    8.78  100.00   12.13   24.00
#
#           TAX  PTRATIO       B   LSTAT
# count  506.00   506.00  506.00  506.00
# mean   408.24    18.46  356.67   12.65
# std    168.54     2.16   91.29    7.14
# min    187.00    12.60    0.32    1.73
# 25%    279.00    17.40  375.38    6.95
# ...

# %%
"""
Summary statistics provides a general idea of each feature and the target, 
but visualization reveals the information more clearly. 

It’s a good practice to visualize and inspect the distribution column by column.
"""

california_housing.hist(column='AveRooms',bins=20,figsize=(15,5))
plt.show()

california_housing['AveRooms'].plot(kind='hist',ylim=(0,25000),xlim=(0,150))
plt.show()

california_housing.hist(column='AveRooms', bins=20)
plt.show()

"""
The distribution of AveRooms appears normal and symmetric. 
The symmetry aligns with what we observed from the output of describe()

Informative data visualization not only reveals insights, but they are invaluable to communicate findings to stakeholders.
"""
# Out:
# '\nThe distribution of AveRooms appears normal and symmetric. \nThe symmetry aligns with what we observed from the output of describe()\n\nInformative data visualization not only reveals insights, but they are invaluable to communicate findings to stakeholders.\n'

# %%
#CHAS only takes on two values, 0 and 1, with most of them 0’s. It is consistent with what the describe() reports; specifically, the third quartile of CHAS is 0.
boston.hist(column='CHAS')
plt.show()

#The distribution of RM appears normal and symmetric. The symmetry aligns with what we observed from the output of describe(), as the mean of RM 6.28 is close to its median 6.21.
boston.hist(column='RM', bins=20)
plt.show()
